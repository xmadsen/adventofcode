# %%
#!/usr/bin/env python
import sys
from collections import defaultdict
import time as realtime
from operator import itemgetter
from datetime import datetime
input_file = sys.argv[1]

with open("input/day4.txt") as file:
    input_values = [line.strip('\n') for line in file.readlines()]

# %%
input_values[:10]
# Out:
# ['[1518-09-16 23:57] Guard #1889 begins shift',
#  '[1518-04-16 00:03] Guard #2897 begins shift',
#  '[1518-04-29 23:57] Guard #1663 begins shift',
#  '[1518-05-27 00:47] wakes up',
#  '[1518-04-27 23:50] Guard #661 begins shift',
#  '[1518-08-29 00:58] wakes up',
#  '[1518-09-26 00:48] falls asleep',
#  '[1518-07-16 00:43] wakes up',
#  '[1518-08-17 00:26] falls asleep',
#  '[1518-08-17 00:53] wakes up']

# %%
records = []
for input_record in input_values:
    this_record = {}
    this_record['timedate'] = datetime.strptime(
        input_record[:18], '[%Y-%m-%d %H:%M]')
    this_record['event'] = input_record[19:]
    records.append(this_record)
sorted_records = sorted(records, key=lambda i: i['timedate'])

# %%
sorted_records[:10]
# Out:
# [{'timedate': datetime.datetime(1518, 4, 5, 0, 2),
#   'event': 'Guard #2459 begins shift'},
#  {'timedate': datetime.datetime(1518, 4, 5, 0, 26), 'event': 'falls asleep'},
#  {'timedate': datetime.datetime(1518, 4, 5, 0, 33), 'event': 'wakes up'},
#  {'timedate': datetime.datetime(1518, 4, 5, 0, 40), 'event': 'falls asleep'},
#  {'timedate': datetime.datetime(1518, 4, 5, 0, 41), 'event': 'wakes up'},
#  {'timedate': datetime.datetime(1518, 4, 5, 23, 56),
#   'event': 'Guard #2633 begins shift'},
#  {'timedate': datetime.datetime(1518, 4, 6, 0, 18), 'event': 'falls asleep'},
#  {'timedate': datetime.datetime(1518, 4, 6, 0, 40), 'event': 'wakes up'},
#  {'timedate': datetime.datetime(1518, 4, 6, 23, 54),
#   'event': 'Guard #3121 begins shift'},
#  {'timedate': datetime.datetime(1518, 4, 7, 0, 4), 'event': 'falls asleep'}]

# %%
schedules = defaultdict(list)
for record in sorted_records:
    schedules[str(record['timedate'].month)+" "+\
              str(record['timedate'].day)].append([record['timedate'].minute, 
                                                   record['event']])

# %%
schedules
# Out:
# defaultdict(list,
#             {'4 5': [[2, 'Guard #2459 begins shift'],
#               [26, 'falls asleep'],
#               [33, 'wakes up'],
#               [40, 'falls asleep'],
#               [41, 'wakes up'],
#               [56, 'Guard #2633 begins shift']],
#              '4 6': [[18, 'falls asleep'],
#               [40, 'wakes up'],
#               [54, 'Guard #3121 begins shift']],
#              '4 7': [[4, 'falls asleep'],
#               [6, 'wakes up'],
#               [27, 'falls asleep'],
#               [58, 'wakes up'],
#               [50, 'Guard #2897 begins shift']],
#              '4 8': [[1, 'falls asleep'],
#               [13, 'wakes up'],
#               [47, 'Guard #1291 begins shift']],
#              '4 9': [[1, 'falls asleep'],
#               [39, 'wakes up'],
#               [59, 'Guard #61 begins shift']],
#              '4 10': [[11, 'falls asleep'],
#               [49, 'wakes up'],
#               [58, 'Guard #1931 begins shift']],
#              '4 11': [[15, 'falls asleep'],
#               [54, 'wakes up'],
#               [57, 'falls asleep'],
#               [59, 'wakes up'],
#               [58, 'Guard #1471 begins shift']],
#              '4 12': [[24, 'falls asleep'],
#               [50, 'wakes up'],
#               [57, 'falls asleep'],
#               [58, 'wakes up'],
#               [59, 'Guard #2633 begins shift']],
#              '4 13': [[23, 'falls asleep'],
#               [35, 'wakes up'],
#               [58, 'Guard #661 begins shift']],
#              '4 14': [[28, 'falls asleep'], [31, 'wakes up']],
#              '4 15': [[0, 'Guard #467 begins shift'],
#               [31, 'falls asleep'],
#               [46, 'wakes up']],
#              '4 16': [[3, 'Guard #2897 begins shift'],
#               [34, 'falls asleep'],
#               [35, 'wakes up'],
#               [48, 'falls asleep'],
#               [59, 'wakes up']],
#              '4 17': [[4, 'Guard #947 begins shift'],
#               [28, 'falls asleep'],
#               [58, 'wakes up']],
#              '4 18': [[2, 'Guard #3037 begins shift'],
#               [23, 'falls asleep'],
#               [34, 'wakes up']],
#              '4 19': [[4, 'Guard #2897 begins shift'],
#               [55, 'falls asleep'],
#               [56, 'wakes up']],
#              '4 20': [[1, 'Guard #2459 begins shift'],
#               [30, 'falls asleep'],
#               [33, 'wakes up']],
#              '4 21': [[0, 'Guard #1283 begins shift'],
#               [13, 'falls asleep'],
#               [28, 'wakes up'],
#               [41, 'falls asleep'],
#               [43, 'wakes up']],
#              '4 22': [[1, 'Guard #947 begins shift'],
#               [18, 'falls asleep'],
#               [27, 'wakes up'],
#               [44, 'falls asleep'],
#               [53, 'wakes up'],
#               [56, 'Guard #409 begins shift']],
#              '4 23': [[57, 'falls asleep'],
#               [58, 'wakes up'],
#               [47, 'Guard #1291 begins shift']],
#              '4 24': [[5, 'falls asleep'], [21, 'wakes up']],
#              '4 25': [[0, 'Guard #1889 begins shift'],
#               [38, 'falls asleep'],
#               [40, 'wakes up'],
#               [46, 'Guard #409 begins shift']],
#              '4 26': [[3, 'falls asleep'],
#               [22, 'wakes up'],
#               [32, 'falls asleep'],
#               [42, 'wakes up'],
#               [58, 'Guard #1291 begins shift']],
#              '4 27': [[15, 'falls asleep'],
#               [47, 'wakes up'],
#               [50, 'Guard #661 begins shift']],
#              '4 28': [[3, 'falls asleep'], [16, 'wakes up']],
#              '4 29': [[1, 'Guard #661 begins shift'],
#               [19, 'falls asleep'],
#               [49, 'wakes up'],
#               [57, 'Guard #1663 begins shift']],
#              '4 30': [[19, 'falls asleep'],
#               [55, 'wakes up'],
#               [56, 'Guard #1471 begins shift']],
#              '5 1': [[31, 'falls asleep'],
#               [49, 'wakes up'],
#               [58, 'Guard #947 begins shift']],
#              '5 2': [[41, 'falls asleep'],
#               [46, 'wakes up'],
#               [49, 'falls asleep'],
#               [59, 'wakes up']],
#              '5 3': [[2, 'Guard #947 begins shift'],
#               [26, 'falls asleep'],
#               [33, 'wakes up'],
#               [39, 'falls asleep'],
#               [56, 'wakes up'],
#               [59, 'Guard #2633 begins shift']],
#              '5 4': [[21, 'falls asleep'],
#               [30, 'wakes up'],
#               [37, 'falls asleep'],
#               [56, 'wakes up'],
#               [58, 'Guard #661 begins shift']],
#              '5 5': [[27, 'falls asleep'], [58, 'wakes up']],
#              '5 6': [[3, 'Guard #1283 begins shift'],
#               [37, 'falls asleep'],
#               [50, 'wakes up']],
#              '5 7': [[2, 'Guard #947 begins shift'],
#               [18, 'falls asleep'],
#               [29, 'wakes up'],
#               [41, 'falls asleep'],
#               [47, 'wakes up']],
#              '5 8': [[2, 'Guard #2447 begins shift'],
#               [14, 'falls asleep'],
#               [40, 'wakes up'],
#               [57, 'Guard #2633 begins shift']],
#              '5 9': [[9, 'falls asleep'],
#               [37, 'wakes up'],
#               [46, 'falls asleep'],
#               [47, 'wakes up'],
#               [50, 'falls asleep'],
#               [57, 'wakes up']],
#              '5 10': [[2, 'Guard #409 begins shift'],
#               [35, 'falls asleep'],
#               [38, 'wakes up'],
#               [51, 'Guard #2459 begins shift']],
#              '5 11': [[4, 'falls asleep'], [5, 'wakes up']],
#              '5 12': [[0, 'Guard #2819 begins shift'],
#               [47, 'falls asleep'],
#               [49, 'wakes up']],
#              '5 13': [[4, 'Guard #2633 begins shift'],
#               [23, 'falls asleep'],
#               [41, 'wakes up']],
#              '5 14': [[4, 'Guard #1433 begins shift'],
#               [45, 'falls asleep'],
#               [53, 'wakes up']],
#              '5 15': [[4, 'Guard #2633 begins shift'],
#               [24, 'falls asleep'],
#               [43, 'wakes up']],
#              '5 16': [[0, 'Guard #1931 begins shift'],
#               [51, 'falls asleep'],
#               [55, 'wakes up'],
#               [54, 'Guard #1471 begins shift']],
#              '5 17': [[5, 'falls asleep'],
#               [17, 'wakes up'],
#               [33, 'falls asleep'],
#               [47, 'wakes up'],
#               [57, 'falls asleep'],
#               [58, 'wakes up']],
#              '5 18': [[3, 'Guard #409 begins shift'],
#               [21, 'falls asleep'],
#               [48, 'wakes up'],
#               [56, 'Guard #2633 begins shift']],
#              '5 19': [[19, 'falls asleep'],
#               [34, 'wakes up'],
#               [53, 'Guard #3307 begins shift']],
#              '5 20': [[4, 'falls asleep'],
#               [44, 'wakes up'],
#               [57, 'Guard #2897 begins shift']],
#              '5 21': [[13, 'falls asleep'],
#               [18, 'wakes up'],
#               [35, 'falls asleep'],
#               [36, 'wakes up'],
#               [48, 'falls asleep'],
#               [52, 'wakes up']],
#              '5 22': [[1, 'Guard #409 begins shift'],
#               [19, 'falls asleep'],
#               [22, 'wakes up'],
#               [29, 'falls asleep'],
#               [30, 'wakes up']],
#              '5 23': [[4, 'Guard #661 begins shift'],
#               [8, 'falls asleep'],
#               [25, 'wakes up'],
#               [29, 'falls asleep'],
#               [44, 'wakes up'],
#               [48, 'falls asleep'],
#               [54, 'wakes up'],
#               [57, 'falls asleep'],
#               [58, 'wakes up']],
#              '5 24': [[2, 'Guard #2633 begins shift'],
#               [21, 'falls asleep'],
#               [31, 'wakes up'],
#               [36, 'falls asleep'],
#               [40, 'wakes up'],
#               [49, 'falls asleep'],
#               [50, 'wakes up'],
#               [58, 'Guard #661 begins shift']],
#              '5 25': [[8, 'falls asleep'],
#               [28, 'wakes up'],
#               [39, 'falls asleep'],
#               [41, 'wakes up'],
#               [57, 'falls asleep'],
#               [59, 'wakes up'],
#               [48, 'Guard #2633 begins shift']],
#              '5 26': [[0, 'falls asleep'],
#               [40, 'wakes up'],
#               [44, 'falls asleep'],
#               [56, 'wakes up']],
#              '5 27': [[3, 'Guard #61 begins shift'],
#               [7, 'falls asleep'],
#               [20, 'wakes up'],
#               [37, 'falls asleep'],
#               [47, 'wakes up']],
#              '5 28': [[1, 'Guard #1291 begins shift'],
#               [24, 'falls asleep'],
#               [34, 'wakes up'],
#               [38, 'falls asleep'],
#               [41, 'wakes up'],
#               [45, 'falls asleep'],
#               [47, 'wakes up'],
#               [58, 'Guard #947 begins shift']],
#              '5 29': [[11, 'falls asleep'],
#               [33, 'wakes up'],
#               [47, 'falls asleep'],
#               [57, 'wakes up']],
#              '5 30': [[4, 'Guard #3307 begins shift'],
#               [24, 'falls asleep'],
#               [57, 'wakes up'],
#               [48, 'Guard #409 begins shift']],
#              '5 31': [[5, 'falls asleep'],
#               [37, 'wakes up'],
#               [50, 'falls asleep'],
#               [56, 'wakes up']],
#              '6 1': [[4, 'Guard #3307 begins shift'],
#               [11, 'falls asleep'],
#               [36, 'wakes up']],
#              '6 2': [[3, 'Guard #1931 begins shift'],
#               [20, 'falls asleep'],
#               [49, 'wakes up'],
#               [57, 'Guard #2819 begins shift']],
#              '6 3': [[48, 'falls asleep'], [55, 'wakes up']],
#              '6 4': [[0, 'Guard #3307 begins shift'],
#               [31, 'falls asleep'],
#               [32, 'wakes up'],
#               [53, 'falls asleep'],
#               [54, 'wakes up'],
#               [57, 'falls asleep'],
#               [59, 'wakes up'],
#               [58, 'Guard #467 begins shift']],
#              '6 5': [[17, 'falls asleep'],
#               [21, 'wakes up'],
#               [54, 'falls asleep'],
#               [57, 'wakes up']],
#              '6 6': [[4, 'Guard #1663 begins shift'],
#               [41, 'falls asleep'],
#               [46, 'wakes up'],
#               [47, 'Guard #3307 begins shift']],
#              '6 7': [[4, 'falls asleep'],
#               [48, 'wakes up'],
#               [59, 'Guard #61 begins shift']],
#              '6 8': [[15, 'falls asleep'],
#               [28, 'wakes up'],
#               [33, 'falls asleep'],
#               [43, 'wakes up'],
#               [48, 'falls asleep'],
#               [50, 'wakes up'],
#               [59, 'Guard #2633 begins shift']],
#              '6 9': [[11, 'falls asleep'],
#               [34, 'wakes up'],
#               [57, 'Guard #2633 begins shift']],
#              '6 10': [[29, 'falls asleep'], [59, 'wakes up']],
#              '6 11': [[1, 'Guard #1471 begins shift'],
#               [18, 'falls asleep'],
#               [44, 'wakes up'],
#               [58, 'Guard #1931 begins shift']],
#              '6 12': [[23, 'falls asleep'],
#               [58, 'wakes up'],
#               [56, 'Guard #2897 begins shift']],
#              '6 13': [[31, 'falls asleep'],
#               [47, 'wakes up'],
#               [53, 'falls asleep'],
#               [58, 'wakes up'],
#               [46, 'Guard #3307 begins shift']],
#              '6 14': [[4, 'falls asleep'],
#               [7, 'wakes up'],
#               [13, 'falls asleep'],
#               [18, 'wakes up'],
#               [44, 'falls asleep'],
#               [52, 'wakes up']],
#              '6 15': [[2, 'Guard #409 begins shift'],
#               [47, 'falls asleep'],
#               [51, 'wakes up'],
#               [56, 'Guard #61 begins shift']],
#              '6 16': [[7, 'falls asleep'], [54, 'wakes up']],
#              '6 17': [[0, 'Guard #3307 begins shift'],
#               [37, 'falls asleep'],
#               [59, 'wakes up'],
#               [59, 'Guard #1931 begins shift']],
#              '6 18': [[33, 'falls asleep'],
#               [45, 'wakes up'],
#               [52, 'falls asleep'],
#               [55, 'wakes up']],
#              '6 19': [[3, 'Guard #3121 begins shift'],
#               [40, 'falls asleep'],
#               [44, 'wakes up'],
#               [56, 'falls asleep'],
#               [58, 'wakes up'],
#               [49, 'Guard #2819 begins shift']],
#              '6 20': [[1, 'falls asleep'],
#               [44, 'wakes up'],
#               [50, 'Guard #3307 begins shift']],
#              '6 21': [[5, 'falls asleep'],
#               [36, 'wakes up'],
#               [47, 'falls asleep'],
#               [53, 'wakes up']],
#              '6 22': [[1, 'Guard #467 begins shift'],
#               [9, 'falls asleep'],
#               [45, 'wakes up']],
#              '6 23': [[0, 'Guard #947 begins shift'],
#               [28, 'falls asleep'],
#               [50, 'wakes up']],
#              '6 24': [[3, 'Guard #1291 begins shift'],
#               [40, 'falls asleep'],
#               [44, 'wakes up'],
#               [59, 'Guard #3121 begins shift']],
#              '6 25': [[31, 'falls asleep'], [58, 'wakes up']],
#              '6 26': [[0, 'Guard #2897 begins shift'],
#               [25, 'falls asleep'],
#               [48, 'wakes up']],
#              '6 27': [[4, 'Guard #947 begins shift'],
#               [42, 'falls asleep'],
#               [47, 'wakes up']],
#              '6 28': [[0, 'Guard #1889 begins shift'],
#               [29, 'falls asleep'],
#               [31, 'wakes up'],
#               [35, 'falls asleep'],
#               [58, 'wakes up'],
#               [58, 'Guard #419 begins shift']],
#              '6 29': [[54, 'Guard #1283 begins shift']],
#              '6 30': [[0, 'falls asleep'],
#               [14, 'wakes up'],
#               [33, 'falls asleep'],
#               [57, 'wakes up'],
#               [58, 'Guard #1291 begins shift']],
#              '7 1': [[21, 'falls asleep'],
#               [42, 'wakes up'],
#               [48, 'falls asleep'],
#               [56, 'wakes up'],
#               [53, 'Guard #467 begins shift']],
#              '7 2': [[0, 'falls asleep'],
#               [54, 'wakes up'],
#               [58, 'Guard #1931 begins shift']],
#              '7 3': [[11, 'falls asleep'], [43, 'wakes up']],
#              '7 4': [[4, 'Guard #1889 begins shift'],
#               [37, 'falls asleep'],
#               [46, 'wakes up'],
#               [56, 'Guard #1931 begins shift']],
#              '7 5': [[6, 'falls asleep'],
#               [20, 'wakes up'],
#               [25, 'falls asleep'],
#               [28, 'wakes up'],
#               [50, 'falls asleep'],
#               [53, 'wakes up'],
#               [50, 'Guard #1889 begins shift']],
#              '7 6': [[4, 'falls asleep'],
#               [22, 'wakes up'],
#               [49, 'Guard #1663 begins shift']],
#              '7 7': [[4, 'falls asleep'],
#               [10, 'wakes up'],
#               [26, 'falls asleep'],
#               [45, 'wakes up']],
#              '7 8': [[3, 'Guard #2633 begins shift'],
#               [12, 'falls asleep'],
#               [26, 'wakes up'],
#               [38, 'falls asleep'],
#               [43, 'wakes up'],
#               [57, 'falls asleep'],
#               [59, 'wakes up'],
#               [56, 'Guard #661 begins shift']],
#              '7 9': [[22, 'falls asleep'], [28, 'wakes up']],
#              '7 10': [[3, 'Guard #3491 begins shift'],
#               [51, 'Guard #1889 begins shift']],
#              '7 11': [[4, 'falls asleep'],
#               [7, 'wakes up'],
#               [20, 'falls asleep'],
#               [38, 'wakes up'],
#               [53, 'Guard #409 begins shift']],
#              '7 12': [[0, 'falls asleep'],
#               [30, 'wakes up'],
#               [53, 'Guard #3037 begins shift']],
#              '7 13': [[1, 'falls asleep'], [42, 'wakes up']],
#              '7 14': [[0, 'Guard #1889 begins shift'],
#               [11, 'falls asleep'],
#               [59, 'wakes up']],
#              '7 15': [[1, 'Guard #947 begins shift'],
#               [19, 'falls asleep'],
#               [52, 'wakes up']],
#              '7 16': [[2, 'Guard #2447 begins shift'],
#               [38, 'falls asleep'],
#               [43, 'wakes up']],
#              '7 17': [[4, 'Guard #3121 begins shift'],
#               [31, 'falls asleep'],
#               [53, 'wakes up']],
#              '7 18': [[2, 'Guard #1663 begins shift'],
#               [16, 'falls asleep'],
#               [52, 'wakes up']],
#              '7 19': [[4, 'Guard #1283 begins shift'],
#               [9, 'falls asleep'],
#               [40, 'wakes up'],
#               [43, 'falls asleep'],
#               [51, 'wakes up']],
#              '7 20': [[0, 'Guard #467 begins shift'],
#               [30, 'falls asleep'],
#               [40, 'wakes up'],
#               [56, 'Guard #2633 begins shift']],
#              '7 21': [[12, 'falls asleep'],
#               [24, 'wakes up'],
#               [29, 'falls asleep'],
#               [44, 'wakes up'],
#               [49, 'falls asleep'],
#               [55, 'wakes up']],
#              '7 22': [[0, 'Guard #1889 begins shift'],
#               [11, 'falls asleep'],
#               [57, 'wakes up'],
#               [59, 'Guard #61 begins shift']],
#              '7 23': [[24, 'falls asleep'], [57, 'wakes up']],
#              '7 24': [[1, 'Guard #1291 begins shift'],
#               [8, 'falls asleep'],
#               [30, 'wakes up'],
#               [54, 'falls asleep'],
#               [55, 'wakes up'],
#               [57, 'Guard #3121 begins shift']],
#              '7 25': [[6, 'falls asleep'],
#               [7, 'wakes up'],
#               [50, 'Guard #1291 begins shift']],
#              '7 26': [[0, 'falls asleep'], [57, 'wakes up']],
#              '7 27': [[4, 'Guard #2459 begins shift'],
#               [10, 'falls asleep'],
#               [56, 'wakes up'],
#               [59, 'Guard #947 begins shift']],
#              '7 28': [[34, 'falls asleep'], [57, 'wakes up']],
#              '7 29': [[0, 'Guard #2447 begins shift'],
#               [26, 'falls asleep'],
#               [49, 'wakes up']],
#              '7 30': [[1, 'Guard #3307 begins shift'],
#               [38, 'falls asleep'],
#               [54, 'wakes up']],
#              '7 31': [[3, 'Guard #3491 begins shift']],
#              '8 1': [[0, 'Guard #61 begins shift'],
#               [10, 'falls asleep'],
#               [42, 'wakes up'],
#               [59, 'Guard #1433 begins shift']],
#              '8 2': [[40, 'falls asleep'], [53, 'wakes up']],
#              '8 3': [[4, 'Guard #1433 begins shift'],
#               [6, 'falls asleep'],
#               [25, 'wakes up'],
#               [54, 'Guard #2459 begins shift']],
#              '8 4': [[2, 'falls asleep'],
#               [52, 'wakes up'],
#               [56, 'Guard #947 begins shift']],
#              '8 5': [[40, 'falls asleep'], [45, 'wakes up']],
#              '8 6': [[2, 'Guard #947 begins shift'],
#               [42, 'falls asleep'],
#               [49, 'wakes up']],
#              '8 7': [[0, 'Guard #61 begins shift'],
#               [12, 'falls asleep'],
#               [17, 'wakes up'],
#               [29, 'falls asleep'],
#               [41, 'wakes up'],
#               [50, 'falls asleep'],
#               [51, 'wakes up'],
#               [54, 'falls asleep'],
#               [59, 'wakes up'],
#               [56, 'Guard #1283 begins shift']],
#              '8 8': [[10, 'falls asleep'],
#               [39, 'wakes up'],
#               [48, 'Guard #1663 begins shift']],
#              '8 9': [[1, 'falls asleep'],
#               [20, 'wakes up'],
#               [39, 'falls asleep'],
#               [42, 'wakes up']],
#              '8 10': [[2, 'Guard #1663 begins shift'],
#               [33, 'falls asleep'],
#               [49, 'wakes up']],
#              '8 11': [[2, 'Guard #1931 begins shift'],
#               [17, 'falls asleep'],
#               [44, 'wakes up'],
#               [58, 'Guard #661 begins shift']],
#              '8 12': [[7, 'falls asleep'], [27, 'wakes up']],
#              '8 13': [[0, 'Guard #947 begins shift'],
#               [43, 'falls asleep'],
#               [48, 'wakes up'],
#               [56, 'Guard #1291 begins shift']],
#              '8 14': [[29, 'falls asleep'], [43, 'wakes up']],
#              '8 15': [[4, 'Guard #2447 begins shift'],
#               [41, 'falls asleep'],
#               [56, 'wakes up'],
#               [59, 'Guard #2459 begins shift']],
#              '8 16': [[21, 'falls asleep'],
#               [38, 'wakes up'],
#               [48, 'falls asleep'],
#               [58, 'wakes up']],
#              '8 17': [[4, 'Guard #1283 begins shift'],
#               [26, 'falls asleep'],
#               [40, 'wakes up'],
#               [43, 'falls asleep'],
#               [44, 'wakes up'],
#               [50, 'falls asleep'],
#               [53, 'wakes up']],
#              '8 18': [[1, 'Guard #419 begins shift'],
#               [57, 'Guard #467 begins shift']],
#              '8 19': [[26, 'falls asleep'],
#               [38, 'wakes up'],
#               [46, 'Guard #3307 begins shift']],
#              '8 20': [[3, 'falls asleep'],
#               [57, 'wakes up'],
#               [51, 'Guard #409 begins shift']],
#              '8 21': [[1, 'falls asleep'],
#               [13, 'wakes up'],
#               [30, 'falls asleep'],
#               [54, 'wakes up']],
#              '8 22': [[0, 'Guard #3491 begins shift'],
#               [46, 'Guard #61 begins shift']],
#              '8 23': [[4, 'falls asleep'], [26, 'wakes up']],
#              '8 24': [[4, 'Guard #1291 begins shift'],
#               [20, 'falls asleep'],
#               [23, 'wakes up'],
#               [33, 'falls asleep'],
#               [39, 'wakes up'],
#               [56, 'falls asleep'],
#               [59, 'wakes up']],
#              '8 25': [[1, 'Guard #467 begins shift'],
#               [39, 'falls asleep'],
#               [41, 'wakes up']],
#              '8 26': [[3, 'Guard #1433 begins shift'],
#               [33, 'falls asleep'],
#               [40, 'wakes up'],
#               [43, 'falls asleep'],
#               [47, 'wakes up']],
#              '8 27': [[1, 'Guard #947 begins shift'],
#               [15, 'falls asleep'],
#               [25, 'wakes up']],
#              '8 28': [[3, 'Guard #3121 begins shift'],
#               [21, 'falls asleep'],
#               [27, 'wakes up'],
#               [37, 'falls asleep'],
#               [45, 'wakes up'],
#               [57, 'Guard #1433 begins shift']],
#              '8 29': [[30, 'falls asleep'],
#               [46, 'wakes up'],
#               [51, 'falls asleep'],
#               [58, 'wakes up'],
#               [58, 'Guard #2633 begins shift']],
#              '8 30': [[34, 'falls asleep'], [56, 'wakes up']],
#              '8 31': [[2, 'Guard #3037 begins shift'],
#               [24, 'falls asleep'],
#               [39, 'wakes up']],
#              '9 1': [[3, 'Guard #1471 begins shift'],
#               [24, 'falls asleep'],
#               [36, 'wakes up'],
#               [40, 'falls asleep'],
#               [45, 'wakes up']],
#              '9 2': [[1, 'Guard #1433 begins shift'],
#               [22, 'falls asleep'],
#               [52, 'wakes up'],
#               [55, 'falls asleep'],
#               [56, 'wakes up'],
#               [56, 'Guard #947 begins shift']],
#              '9 3': [[44, 'falls asleep'], [50, 'wakes up']],
#              '9 4': [[1, 'Guard #2633 begins shift'],
#               [32, 'falls asleep'],
#               [45, 'wakes up']],
#              '9 5': [[4, 'Guard #409 begins shift'],
#               [22, 'falls asleep'],
#               [41, 'wakes up'],
#               [59, 'Guard #1283 begins shift']],
#              '9 6': [[15, 'falls asleep'],
#               [36, 'wakes up'],
#               [42, 'falls asleep'],
#               [49, 'wakes up']],
#              '9 7': [[3, 'Guard #409 begins shift'],
#               [9, 'falls asleep'],
#               [45, 'wakes up'],
#               [49, 'falls asleep'],
#               [55, 'wakes up']],
#              '9 8': [[2, 'Guard #467 begins shift'],
#               [14, 'falls asleep'],
#               [45, 'wakes up'],
#               [53, 'falls asleep'],
#               [57, 'wakes up'],
#               [51, 'Guard #3307 begins shift']],
#              '9 9': [[3, 'falls asleep'],
#               [25, 'wakes up'],
#               [35, 'falls asleep'],
#               [53, 'wakes up'],
#               [48, 'Guard #1931 begins shift']],
#              '9 10': [[4, 'falls asleep'],
#               [20, 'wakes up'],
#               [48, 'falls asleep'],
#               [58, 'wakes up']],
#              '9 11': [[2, 'Guard #2819 begins shift'],
#               [21, 'falls asleep'],
#               [36, 'wakes up'],
#               [58, 'Guard #409 begins shift']],
#              '9 12': [[13, 'falls asleep'],
#               [23, 'wakes up'],
#               [30, 'falls asleep'],
#               [32, 'wakes up'],
#               [49, 'Guard #61 begins shift']],
#              '9 13': [[3, 'falls asleep'],
#               [16, 'wakes up'],
#               [25, 'falls asleep'],
#               [48, 'wakes up']],
#              '9 14': [[0, 'Guard #3121 begins shift'],
#               [21, 'falls asleep'],
#               [31, 'wakes up'],
#               [38, 'falls asleep'],
#               [56, 'wakes up']],
#              '9 15': [[1, 'Guard #2447 begins shift'],
#               [27, 'falls asleep'],
#               [35, 'wakes up'],
#               [42, 'falls asleep'],
#               [55, 'wakes up']],
#              '9 16': [[1, 'Guard #1291 begins shift'],
#               [39, 'falls asleep'],
#               [54, 'wakes up'],
#               [57, 'Guard #1889 begins shift']],
#              '9 17': [[12, 'falls asleep'],
#               [23, 'wakes up'],
#               [36, 'falls asleep'],
#               [41, 'wakes up']],
#              '9 18': [[4, 'Guard #2459 begins shift'],
#               [31, 'falls asleep'],
#               [46, 'wakes up'],
#               [51, 'Guard #2819 begins shift']],
#              '9 19': [[3, 'falls asleep'], [56, 'wakes up']],
#              '9 20': [[2, 'Guard #3121 begins shift'],
#               [8, 'falls asleep'],
#               [48, 'wakes up'],
#               [53, 'Guard #2447 begins shift']],
#              '9 21': [[2, 'falls asleep'],
#               [31, 'wakes up'],
#               [43, 'falls asleep'],
#               [52, 'wakes up']],
#              '9 22': [[2, 'Guard #1663 begins shift'],
#               [9, 'falls asleep'],
#               [10, 'wakes up'],
#               [34, 'falls asleep'],
#               [53, 'wakes up'],
#               [56, 'Guard #1283 begins shift']],
#              '9 23': [[45, 'falls asleep'],
#               [53, 'wakes up'],
#               [59, 'Guard #1291 begins shift']],
#              '9 24': [[31, 'falls asleep'],
#               [42, 'wakes up'],
#               [46, 'falls asleep'],
#               [47, 'wakes up'],
#               [50, 'Guard #1931 begins shift']],
#              '9 25': [[1, 'falls asleep'],
#               [40, 'wakes up'],
#               [50, 'falls asleep'],
#               [57, 'wakes up']],
#              '9 26': [[4, 'Guard #409 begins shift'],
#               [48, 'falls asleep'],
#               [56, 'wakes up'],
#               [56, 'Guard #2633 begins shift']],
#              '9 27': [[17, 'falls asleep'],
#               [56, 'wakes up'],
#               [52, 'Guard #947 begins shift']],
#              '9 28': [[3, 'falls asleep'],
#               [12, 'wakes up'],
#               [44, 'falls asleep'],
#               [52, 'wakes up'],
#               [52, 'Guard #2819 begins shift']],
#              '9 29': [[5, 'falls asleep'], [30, 'wakes up']],
#              '9 30': [[2, 'Guard #1291 begins shift'],
#               [7, 'falls asleep'],
#               [52, 'wakes up'],
#               [56, 'falls asleep'],
#               [58, 'wakes up']],
#              '10 1': [[3, 'Guard #61 begins shift'],
#               [17, 'falls asleep'],
#               [33, 'wakes up'],
#               [43, 'falls asleep'],
#               [47, 'wakes up']],
#              '10 2': [[2, 'Guard #3037 begins shift'],
#               [12, 'falls asleep'],
#               [38, 'wakes up'],
#               [50, 'falls asleep'],
#               [58, 'wakes up'],
#               [58, 'Guard #409 begins shift']],
#              '10 3': [[17, 'falls asleep'], [31, 'wakes up']],
#              '10 4': [[3, 'Guard #947 begins shift'],
#               [9, 'falls asleep'],
#               [24, 'wakes up'],
#               [43, 'falls asleep'],
#               [46, 'wakes up']],
#              '10 5': [[1, 'Guard #3121 begins shift'],
#               [17, 'falls asleep'],
#               [35, 'wakes up']],
#              '10 6': [[0, 'Guard #3037 begins shift'],
#               [13, 'falls asleep'],
#               [26, 'wakes up'],
#               [36, 'falls asleep'],
#               [49, 'wakes up'],
#               [57, 'Guard #3037 begins shift']],
#              '10 7': [[9, 'falls asleep'], [32, 'wakes up']],
#              '10 8': [[0, 'Guard #1433 begins shift'],
#               [48, 'falls asleep'],
#               [50, 'wakes up']],
#              '10 9': [[1, 'Guard #2897 begins shift'],
#               [19, 'falls asleep'],
#               [38, 'wakes up'],
#               [47, 'falls asleep'],
#               [56, 'wakes up']],
#              '10 10': [[2, 'Guard #3037 begins shift'],
#               [32, 'falls asleep'],
#               [47, 'wakes up'],
#               [55, 'falls asleep'],
#               [56, 'wakes up']],
#              '10 11': [[4, 'Guard #661 begins shift'],
#               [19, 'falls asleep'],
#               [24, 'wakes up'],
#               [43, 'falls asleep'],
#               [50, 'wakes up'],
#               [53, 'falls asleep'],
#               [55, 'wakes up']],
#              '10 12': [[2, 'Guard #947 begins shift'],
#               [47, 'falls asleep'],
#               [53, 'wakes up'],
#               [56, 'Guard #61 begins shift']],
#              '10 13': [[14, 'falls asleep'],
#               [44, 'wakes up'],
#               [49, 'Guard #61 begins shift']],
#              '10 14': [[0, 'falls asleep'], [54, 'wakes up']],
#              '10 15': [[0, 'Guard #947 begins shift'],
#               [20, 'falls asleep'],
#               [52, 'wakes up'],
#               [56, 'Guard #2447 begins shift']],
#              '10 16': [[13, 'falls asleep'],
#               [57, 'wakes up'],
#               [56, 'Guard #3307 begins shift']],
#              '10 17': [[35, 'falls asleep'], [52, 'wakes up']],
#              '10 18': [[1, 'Guard #947 begins shift'],
#               [36, 'falls asleep'],
#               [54, 'wakes up']],
#              '10 19': [[0, 'Guard #2633 begins shift'],
#               [8, 'falls asleep'],
#               [39, 'wakes up'],
#               [46, 'falls asleep'],
#               [47, 'wakes up'],
#               [56, 'falls asleep'],
#               [59, 'wakes up'],
#               [56, 'Guard #2447 begins shift']],
#              '10 20': [[14, 'falls asleep'], [42, 'wakes up']],
#              '10 21': [[0, 'Guard #3307 begins shift'],
#               [10, 'falls asleep'],
#               [44, 'wakes up'],
#               [58, 'Guard #3491 begins shift']],
#              '10 23': [[1, 'Guard #409 begins shift'],
#               [11, 'falls asleep'],
#               [16, 'wakes up'],
#               [34, 'falls asleep'],
#               [39, 'wakes up'],
#               [42, 'falls asleep'],
#               [57, 'wakes up']],
#              '10 24': [[4, 'Guard #167 begins shift']],
#              '10 25': [[2, 'Guard #661 begins shift'],
#               [54, 'falls asleep'],
#               [55, 'wakes up']],
#              '10 26': [[2, 'Guard #61 begins shift'],
#               [19, 'falls asleep'],
#               [47, 'wakes up'],
#               [58, 'Guard #2897 begins shift']],
#              '10 27': [[35, 'falls asleep'],
#               [41, 'wakes up'],
#               [50, 'falls asleep'],
#               [56, 'wakes up'],
#               [50, 'Guard #3121 begins shift']],
#              '10 28': [[4, 'falls asleep'], [53, 'wakes up']],
#              '10 29': [[0, 'Guard #3121 begins shift'],
#               [14, 'falls asleep'],
#               [33, 'wakes up'],
#               [58, 'Guard #2459 begins shift']],
#              '10 30': [[10, 'falls asleep'],
#               [44, 'wakes up'],
#               [52, 'Guard #1291 begins shift']],
#              '10 31': [[0, 'falls asleep'],
#               [11, 'wakes up'],
#               [54, 'Guard #409 begins shift']],
#              '11 1': [[1, 'falls asleep'],
#               [48, 'wakes up'],
#               [57, 'Guard #2459 begins shift']],
#              '11 2': [[23, 'falls asleep'],
#               [35, 'wakes up'],
#               [42, 'falls asleep'],
#               [51, 'wakes up'],
#               [57, 'Guard #947 begins shift']],
#              '11 3': [[44, 'falls asleep'],
#               [49, 'wakes up'],
#               [53, 'falls asleep'],
#               [57, 'wakes up'],
#               [48, 'Guard #1433 begins shift']],
#              '11 4': [[5, 'falls asleep'],
#               [16, 'wakes up'],
#               [54, 'Guard #1433 begins shift']],
#              '11 5': [[3, 'falls asleep'], [53, 'wakes up']],
#              '11 6': [[2, 'Guard #3307 begins shift'],
#               [22, 'falls asleep'],
#               [52, 'wakes up'],
#               [59, 'Guard #2459 begins shift']],
#              '11 7': [[12, 'falls asleep'], [34, 'wakes up']],
#              '11 8': [[4, 'Guard #61 begins shift'],
#               [8, 'falls asleep'],
#               [10, 'wakes up'],
#               [34, 'falls asleep'],
#               [43, 'wakes up'],
#               [58, 'Guard #3121 begins shift']],
#              '11 9': [[29, 'falls asleep'], [33, 'wakes up']],
#              '11 10': [[2, 'Guard #2897 begins shift'],
#               [10, 'falls asleep'],
#               [28, 'wakes up'],
#               [39, 'falls asleep'],
#               [47, 'wakes up']],
#              '11 11': [[4, 'Guard #2819 begins shift'],
#               [12, 'falls asleep'],
#               [24, 'wakes up'],
#               [37, 'falls asleep'],
#               [45, 'wakes up'],
#               [58, 'Guard #2819 begins shift']],
#              '11 12': [[11, 'falls asleep'],
#               [17, 'wakes up'],
#               [22, 'falls asleep'],
#               [51, 'wakes up']],
#              '11 13': [[2, 'Guard #2447 begins shift'],
#               [20, 'falls asleep'],
#               [40, 'wakes up'],
#               [57, 'falls asleep'],
#               [58, 'wakes up'],
#               [57, 'Guard #2459 begins shift']],
#              '11 14': [[28, 'falls asleep'], [58, 'wakes up']],
#              '11 15': [[3, 'Guard #419 begins shift']],
#              '11 16': [[0, 'Guard #1663 begins shift'],
#               [19, 'falls asleep'],
#               [46, 'wakes up']],
#              '11 17': [[0, 'Guard #409 begins shift'],
#               [31, 'falls asleep'],
#               [32, 'wakes up'],
#               [47, 'falls asleep'],
#               [55, 'wakes up']],
#              '11 18': [[4, 'Guard #467 begins shift'],
#               [44, 'falls asleep'],
#               [54, 'wakes up'],
#               [56, 'Guard #3121 begins shift']],
#              '11 19': [[27, 'falls asleep'],
#               [36, 'wakes up'],
#               [42, 'falls asleep'],
#               [49, 'wakes up'],
#               [53, 'falls asleep'],
#               [58, 'wakes up'],
#               [58, 'Guard #1471 begins shift']],
#              '11 20': [[31, 'falls asleep'],
#               [48, 'wakes up'],
#               [54, 'falls asleep'],
#               [59, 'wakes up']],
#              '11 21': [[0, 'Guard #1471 begins shift'],
#               [38, 'falls asleep'],
#               [40, 'wakes up'],
#               [58, 'Guard #467 begins shift']],
#              '11 22': [[37, 'falls asleep'], [50, 'wakes up']],
#              '11 23': [[4, 'Guard #1663 begins shift'],
#               [19, 'falls asleep'],
#               [56, 'wakes up']]})

# %%
guard_schedules = {}
for day in schedules.items():
    for event in day[1]:
        if "Guard" in event[1]:
            guardid = int(event[1].split(" ")[1][1:])
            if guardid not in guard_schedules:
                guard_schedules[guardid] = []
        if "wakes up" in event[1] or "falls asleep" in event[1]:
            guard_schedules[guardid].append(event[0])

# %%
guard_schedules
# Out:
# {2459: [26,
#   33,
#   40,
#   41,
#   30,
#   33,
#   4,
#   5,
#   10,
#   56,
#   2,
#   52,
#   21,
#   38,
#   48,
#   58,
#   31,
#   46,
#   10,
#   44,
#   23,
#   35,
#   42,
#   51,
#   12,
#   34,
#   28,
#   58],
#  2633: [18,
#   40,
#   23,
#   35,
#   21,
#   30,
#   37,
#   56,
#   9,
#   37,
#   46,
#   47,
#   50,
#   57,
#   23,
#   41,
#   24,
#   43,
#   19,
#   34,
#   21,
#   31,
#   36,
#   40,
#   49,
#   50,
#   0,
#   40,
#   44,
#   56,
#   11,
#   34,
#   29,
#   59,
#   12,
#   26,
#   38,
#   43,
#   57,
#   59,
#   12,
#   24,
#   29,
#   44,
#   49,
#   55,
#   34,
#   56,
#   32,
#   45,
#   17,
#   56,
#   8,
#   39,
#   46,
#   47,
#   56,
#   59],
#  3121: [4,
#   6,
#   27,
#   58,
#   40,
#   44,
#   56,
#   58,
#   31,
#   58,
#   31,
#   53,
#   6,
#   7,
#   21,
#   27,
#   37,
#   45,
#   21,
#   31,
#   38,
#   56,
#   8,
#   48,
#   17,
#   35,
#   4,
#   53,
#   14,
#   33,
#   29,
#   33,
#   27,
#   36,
#   42,
#   49,
#   53,
#   58],
#  2897: [1,
#   13,
#   34,
#   35,
#   48,
#   59,
#   55,
#   56,
#   13,
#   18,
#   35,
#   36,
#   48,
#   52,
#   31,
#   47,
#   53,
#   58,
#   25,
#   48,
#   19,
#   38,
#   47,
#   56,
#   35,
#   41,
#   50,
#   56,
#   10,
#   28,
#   39,
#   47],
#  1291: [1,
#   39,
#   5,
#   21,
#   15,
#   47,
#   24,
#   34,
#   38,
#   41,
#   45,
#   47,
#   40,
#   44,
#   21,
#   42,
#   48,
#   56,
#   8,
#   30,
#   54,
#   55,
#   0,
#   57,
#   29,
#   43,
#   20,
#   23,
#   33,
#   39,
#   56,
#   59,
#   39,
#   54,
#   31,
#   42,
#   46,
#   47,
#   7,
#   52,
#   56,
#   58,
#   0,
#   11],
#  61: [11,
#   49,
#   7,
#   20,
#   37,
#   47,
#   15,
#   28,
#   33,
#   43,
#   48,
#   50,
#   7,
#   54,
#   24,
#   57,
#   10,
#   42,
#   12,
#   17,
#   29,
#   41,
#   50,
#   51,
#   54,
#   59,
#   4,
#   26,
#   3,
#   16,
#   25,
#   48,
#   17,
#   33,
#   43,
#   47,
#   14,
#   44,
#   0,
#   54,
#   19,
#   47,
#   8,
#   10,
#   34,
#   43],
#  1931: [15,
#   54,
#   57,
#   59,
#   51,
#   55,
#   20,
#   49,
#   23,
#   58,
#   33,
#   45,
#   52,
#   55,
#   11,
#   43,
#   6,
#   20,
#   25,
#   28,
#   50,
#   53,
#   17,
#   44,
#   4,
#   20,
#   48,
#   58,
#   1,
#   40,
#   50,
#   57],
#  1471: [24,
#   50,
#   57,
#   58,
#   31,
#   49,
#   5,
#   17,
#   33,
#   47,
#   57,
#   58,
#   18,
#   44,
#   24,
#   36,
#   40,
#   45,
#   31,
#   48,
#   54,
#   59,
#   38,
#   40],
#  661: [28,
#   31,
#   3,
#   16,
#   19,
#   49,
#   27,
#   58,
#   8,
#   25,
#   29,
#   44,
#   48,
#   54,
#   57,
#   58,
#   8,
#   28,
#   39,
#   41,
#   57,
#   59,
#   22,
#   28,
#   7,
#   27,
#   19,
#   24,
#   43,
#   50,
#   53,
#   55,
#   54,
#   55],
#  467: [31,
#   46,
#   17,
#   21,
#   54,
#   57,
#   9,
#   45,
#   0,
#   54,
#   30,
#   40,
#   26,
#   38,
#   39,
#   41,
#   14,
#   45,
#   53,
#   57,
#   44,
#   54,
#   37,
#   50],
#  947: [28,
#   58,
#   18,
#   27,
#   44,
#   53,
#   41,
#   46,
#   49,
#   59,
#   26,
#   33,
#   39,
#   56,
#   18,
#   29,
#   41,
#   47,
#   11,
#   33,
#   47,
#   57,
#   28,
#   50,
#   42,
#   47,
#   19,
#   52,
#   34,
#   57,
#   40,
#   45,
#   42,
#   49,
#   43,
#   48,
#   15,
#   25,
#   44,
#   50,
#   3,
#   12,
#   44,
#   52,
#   9,
#   24,
#   43,
#   46,
#   47,
#   53,
#   20,
#   52,
#   36,
#   54,
#   44,
#   49,
#   53,
#   57],
#  3037: [23,
#   34,
#   1,
#   42,
#   24,
#   39,
#   12,
#   38,
#   50,
#   58,
#   13,
#   26,
#   36,
#   49,
#   9,
#   32,
#   32,
#   47,
#   55,
#   56],
#  1283: [13,
#   28,
#   41,
#   43,
#   37,
#   50,
#   0,
#   14,
#   33,
#   57,
#   9,
#   40,
#   43,
#   51,
#   10,
#   39,
#   26,
#   40,
#   43,
#   44,
#   50,
#   53,
#   15,
#   36,
#   42,
#   49,
#   45,
#   53],
#  409: [57,
#   58,
#   3,
#   22,
#   32,
#   42,
#   35,
#   38,
#   21,
#   48,
#   19,
#   22,
#   29,
#   30,
#   5,
#   37,
#   50,
#   56,
#   47,
#   51,
#   0,
#   30,
#   1,
#   13,
#   30,
#   54,
#   22,
#   41,
#   9,
#   45,
#   49,
#   55,
#   13,
#   23,
#   30,
#   32,
#   48,
#   56,
#   17,
#   31,
#   11,
#   16,
#   34,
#   39,
#   42,
#   57,
#   1,
#   48,
#   31,
#   32,
#   47,
#   55],
#  1889: [38,
#   40,
#   29,
#   31,
#   35,
#   58,
#   37,
#   46,
#   4,
#   22,
#   4,
#   7,
#   20,
#   38,
#   11,
#   59,
#   11,
#   57,
#   12,
#   23,
#   36,
#   41],
#  1663: [19,
#   55,
#   41,
#   46,
#   4,
#   10,
#   26,
#   45,
#   16,
#   52,
#   1,
#   20,
#   39,
#   42,
#   33,
#   49,
#   9,
#   10,
#   34,
#   53,
#   19,
#   46,
#   19,
#   56],
#  2447: [14,
#   40,
#   38,
#   43,
#   26,
#   49,
#   41,
#   56,
#   27,
#   35,
#   42,
#   55,
#   2,
#   31,
#   43,
#   52,
#   13,
#   57,
#   14,
#   42,
#   20,
#   40,
#   57,
#   58],
#  2819: [47,
#   49,
#   48,
#   55,
#   1,
#   44,
#   21,
#   36,
#   3,
#   56,
#   5,
#   30,
#   12,
#   24,
#   37,
#   45,
#   11,
#   17,
#   22,
#   51],
#  1433: [45,
#   53,
#   40,
#   53,
#   6,
#   25,
#   33,
#   40,
#   43,
#   47,
#   30,
#   46,
#   51,
#   58,
#   22,
#   52,
#   55,
#   56,
#   48,
#   50,
#   5,
#   16,
#   3,
#   53],
#  3307: [4,
#   44,
#   24,
#   57,
#   11,
#   36,
#   31,
#   32,
#   53,
#   54,
#   57,
#   59,
#   4,
#   48,
#   4,
#   7,
#   13,
#   18,
#   44,
#   52,
#   37,
#   59,
#   5,
#   36,
#   47,
#   53,
#   38,
#   54,
#   3,
#   57,
#   3,
#   25,
#   35,
#   53,
#   35,
#   52,
#   10,
#   44,
#   22,
#   52],
#  419: [],
#  3491: [],
#  167: []}

# %%
guard_asleeptimes = {}
for guard, times in guard_schedules.items():
    guard_asleeptimes[guard] = {minute: 0 for minute in range(0,60)}
    sleeptimes = [times[i:i+2] for i in range(0, len(times), 2)]
    for timerange in sleeptimes:
        for minute in range(timerange[0], timerange[1]):
            guard_asleeptimes[guard][minute] += 1

# %%
guard_totalsleep = {}
for guard, minutes in guard_asleeptimes.items():
    guard_totalsleep[guard] = sum(minutes.values())

# %%
sleepiest_guardid = max(guard_totalsleep, key=guard_totalsleep.get)
most_common_sleeptime = max(guard_asleeptimes[sleepiest_guardid], key=guard_asleeptimes[sleepiest_guardid].get)

# %%
sleepiest_guardid * most_common_sleeptime
# Out:
# 76357

# %%
maxcount = 0
maxid = 0
maxminute = 0
for guard, minutes in guard_asleeptimes.items():
    most_slept_minute = max(minutes, key=minutes.get)
    count = max(minutes.values())
    if count > maxcount:
        maxcount = count
        maxid = guard
        maxminute = most_slept_minute

# %%
print( maxid * maxminute)
# Out:
# 41668
